# %%
import torch
import os
print("PyTorch has version {}".format(torch.__version__))
# Out:
# PyTorch has version 1.12.0

# %%
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

class GCN(torch.nn.Module):
  def __init__(self, input_dim, hidden_dim, output_dim, num_layers,
               dropout, return_embeds=False):
    super(GCN, self).__init__()
    # We shall define the neural network architecture here that will be important for the forward pass
    self.convs = torch.nn.ModuleList([GCNConv(input_dim, hidden_dim)] +
                                     [GCNConv(hidden_dim, hidden_dim) for _ in range(num_layers-2)] +
                                     [GCNConv(hidden_dim, output_dim)])
    self.bns = torch.nn.ModuleList([torch.nn.BatchNorm1d(hidden_dim) for _ in range(num_layers-1)])
    self.softmax = torch.nn.LogSoftmax(dim=1)
    self.dropout = dropout
    self.return_embeds = return_embeds

  def reset_parameters(self):
    for conv in self.convs:
      conv.reset_parameters()
    for bn in self.bns:
      bn.reset_parameters()
  
  def forward(self, x, adj_t):
    out = None
    for conv, bn in zip(self.convs[:-1], self.bns):
      x = conv(x, adj_t)
      x = bn(x)
      x = F.relu(x)
      x = F.dropout(x,p=self.dropout,training=self.training)
    x = self.convs[-1](x, adj_t)
    out = x if self.return_embeds else self.softmax(x)
    return out

# %%
def train(model, data, train_idx, optimizer, loss_fn):
  model.train()
  loss = 0
  
  optimizer.zero_grad()
  out = model(data.x, data.adj_t)
  loss = loss_fn(out[train_idx], data.y[train_idx].squeeze())
  
  loss.backward()
  optimizer.step()
  return loss.item()

# %%
# Test function here
@torch.no_grad()
def test(model, data, split_idx, evaluator, save_model_results=False):
    # TODO: Implement a function that tests the model by 
    # using the given split_idx and evaluator.
    model.eval()

    # The output of model on all data
    out = None

    ############# Your code here ############
    ## (~1 line of code)
    ## Note:
    ## 1. No index slicing here
    out = model(data.x, data.adj_t)
    #########################################

    y_pred = out.argmax(dim=-1, keepdim=True)

    train_acc = evaluator.eval({
        'y_true': data.y[split_idx['train']],
        'y_pred': y_pred[split_idx['train']],
    })['acc']
    valid_acc = evaluator.eval({
        'y_true': data.y[split_idx['valid']],
        'y_pred': y_pred[split_idx['valid']],
    })['acc']
    test_acc = evaluator.eval({
        'y_true': data.y[split_idx['test']],
        'y_pred': y_pred[split_idx['test']],
    })['acc']

    if save_model_results:
      print ("Saving Model Predictions")

      data = {}
      data['y_pred'] = y_pred.view(-1).cpu().detach().numpy()

      df = pd.DataFrame(data=data)
      # Save locally as csv
      df.to_csv('ogbn-arxiv_node.csv', sep=',', index=False)


    return train_acc, valid_acc, test_acc

# %%
import torch_geometric.transforms as T
from ogb.nodeproppred import PygNodePropPredDataset, Evaluator

if 'IS_GRADESCOPE_ENV' not in os.environ:
  dataset_name = 'ogbn-arxiv'
  dataset = PygNodePropPredDataset(name=dataset_name,
                                  transform=T.ToSparseTensor())
  data = dataset[0]

  # Make the adjacency matrix to symmetric
  data.adj_t = data.adj_t.to_symmetric()

  device = 'cuda' if torch.cuda.is_available() else 'cpu'

  # If you use GPU, the device should be cuda
  print('Device: {}'.format(device))

  data = data.to(device)
  split_idx = dataset.get_idx_split()
  train_idx = split_idx['train'].to(device)
# Out:
# Device: cuda

# %%
# Please do not change the args
if 'IS_GRADESCOPE_ENV' not in os.environ:
  args = {
      'device': device,
      'num_layers': 3,
      'hidden_dim': 256,
      'dropout': 0.5,
      'lr': 0.01,
      'epochs': 100,
  }
  args

# %%
if 'IS_GRADESCOPE_ENV' not in os.environ:
  model = GCN(data.num_features, args['hidden_dim'],
              dataset.num_classes, args['num_layers'],
              args['dropout']).to(device)
  evaluator = Evaluator(name='ogbn-arxiv')

# %%
import copy
if 'IS_GRADESCOPE_ENV' not in os.environ:
  # reset the parameters to initial random value
  model.reset_parameters()

  optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
  loss_fn = F.nll_loss

  best_model = None
  best_valid_acc = 0

  for epoch in range(1, 1 + args["epochs"]):
    loss = train(model, data, train_idx, optimizer, loss_fn)
    result = test(model, data, split_idx, evaluator)
    train_acc, valid_acc, test_acc = result
    if valid_acc > best_valid_acc:
        best_valid_acc = valid_acc
        best_model = copy.deepcopy(model)
    print(f'Epoch: {epoch:02d}, '
          f'Loss: {loss:.4f}, '
          f'Train: {100 * train_acc:.2f}%, '
          f'Valid: {100 * valid_acc:.2f}% '
          f'Test: {100 * test_acc:.2f}%')
# Out:
# Epoch: 01, Loss: 4.2313, Train: 21.68%, Valid: 26.97% Test: 24.27%
# Epoch: 02, Loss: 2.3564, Train: 24.07%, Valid: 22.97% Test: 28.06%
# Epoch: 03, Loss: 1.9433, Train: 26.65%, Valid: 24.03% Test: 29.25%
# Epoch: 04, Loss: 1.7527, Train: 34.99%, Valid: 30.27% Test: 34.57%
# Epoch: 05, Loss: 1.6576, Train: 37.89%, Valid: 33.40% Test: 31.67%
# Epoch: 06, Loss: 1.5891, Train: 41.71%, Valid: 35.46% Test: 33.42%
# Epoch: 07, Loss: 1.5130, Train: 41.68%, Valid: 29.31% Test: 27.20%
# Epoch: 08, Loss: 1.4587, Train: 40.68%, Valid: 26.02% Test: 23.04%
# Epoch: 09, Loss: 1.4214, Train: 40.69%, Valid: 27.28% Test: 24.76%
# Epoch: 10, Loss: 1.3853, Train: 41.22%, Valid: 33.24% Test: 35.89%
# Epoch: 11, Loss: 1.3488, Train: 40.65%, Valid: 33.74% Test: 37.47%
# Epoch: 12, Loss: 1.3183, Train: 40.35%, Valid: 34.05% Test: 38.26%
# Epoch: 13, Loss: 1.2979, Train: 40.61%, Valid: 35.94% Test: 40.11%
# Epoch: 14, Loss: 1.2761, Train: 40.62%, Valid: 36.83% Test: 41.19%
# Epoch: 15, Loss: 1.2575, Train: 41.55%, Valid: 38.19% Test: 43.06%
# Epoch: 16, Loss: 1.2375, Train: 42.93%, Valid: 39.66% Test: 44.33%
# Epoch: 17, Loss: 1.2215, Train: 45.42%, Valid: 41.96% Test: 46.25%
# Epoch: 18, Loss: 1.2055, Train: 48.25%, Valid: 45.26% Test: 49.31%
# Epoch: 19, Loss: 1.1971, Train: 51.12%, Valid: 48.76% Test: 52.77%
# Epoch: 20, Loss: 1.1823, Train: 53.67%, Valid: 52.33% Test: 56.09%
# Epoch: 21, Loss: 1.1668, Train: 55.72%, Valid: 55.07% Test: 58.64%
# Epoch: 22, Loss: 1.1597, Train: 57.89%, Valid: 57.62% Test: 60.81%
# Epoch: 23, Loss: 1.1492, Train: 60.37%, Valid: 60.53% Test: 63.04%
# Epoch: 24, Loss: 1.1365, Train: 62.37%, Valid: 62.63% Test: 64.32%
# Epoch: 25, Loss: 1.1274, Train: 63.66%, Valid: 63.84% Test: 64.89%
# Epoch: 26, Loss: 1.1237, Train: 64.54%, Valid: 64.62% Test: 65.28%
# Epoch: 27, Loss: 1.1160, Train: 65.21%, Valid: 65.39% Test: 65.98%
# Epoch: 28, Loss: 1.1080, Train: 65.60%, Valid: 65.73% Test: 66.52%
# Epoch: 29, Loss: 1.1017, Train: 65.82%, Valid: 65.77% Test: 66.90%
# Epoch: 30, Loss: 1.0950, Train: 66.05%, Valid: 65.61% Test: 66.94%
# Epoch: 31, Loss: 1.0880, Train: 66.24%, Valid: 65.69% Test: 67.08%
# Epoch: 32, Loss: 1.0828, Train: 66.57%, Valid: 65.98% Test: 67.35%
# Epoch: 33, Loss: 1.0768, Train: 66.89%, Valid: 66.45% Test: 67.62%
# Epoch: 34, Loss: 1.0721, Train: 67.46%, Valid: 67.02% Test: 68.08%
# Epoch: 35, Loss: 1.0681, Train: 68.12%, Valid: 67.59% Test: 68.57%
# Epoch: 36, Loss: 1.0602, Train: 68.89%, Valid: 68.43% Test: 68.78%
# Epoch: 37, Loss: 1.0548, Train: 69.39%, Valid: 68.80% Test: 68.70%
# Epoch: 38, Loss: 1.0544, Train: 69.68%, Valid: 69.13% Test: 68.61%
# Epoch: 39, Loss: 1.0461, Train: 69.83%, Valid: 69.36% Test: 69.03%
# Epoch: 40, Loss: 1.0431, Train: 69.78%, Valid: 69.45% Test: 69.42%
# Epoch: 41, Loss: 1.0392, Train: 69.74%, Valid: 69.42% Test: 69.54%
# Epoch: 42, Loss: 1.0373, Train: 69.77%, Valid: 69.45% Test: 69.51%
# Epoch: 43, Loss: 1.0328, Train: 69.97%, Valid: 69.66% Test: 69.59%
# Epoch: 44, Loss: 1.0251, Train: 70.08%, Valid: 69.69% Test: 69.62%
# Epoch: 45, Loss: 1.0251, Train: 70.12%, Valid: 69.77% Test: 69.68%
# Epoch: 46, Loss: 1.0177, Train: 70.01%, Valid: 69.62% Test: 69.57%
# Epoch: 47, Loss: 1.0182, Train: 70.16%, Valid: 69.75% Test: 69.59%
# Epoch: 48, Loss: 1.0122, Train: 70.45%, Valid: 69.95% Test: 69.71%
# Epoch: 49, Loss: 1.0103, Train: 70.55%, Valid: 69.97% Test: 69.86%
# Epoch: 50, Loss: 1.0059, Train: 70.67%, Valid: 69.92% Test: 69.82%
# Epoch: 51, Loss: 1.0050, Train: 70.56%, Valid: 69.56% Test: 69.78%
# Epoch: 52, Loss: 1.0018, Train: 70.60%, Valid: 69.45% Test: 69.82%
# Epoch: 53, Loss: 1.0011, Train: 70.93%, Valid: 69.86% Test: 70.02%
# Epoch: 54, Loss: 0.9960, Train: 71.43%, Valid: 70.41% Test: 70.06%
# Epoch: 55, Loss: 0.9925, Train: 71.61%, Valid: 70.47% Test: 69.49%
# Epoch: 56, Loss: 0.9893, Train: 71.72%, Valid: 70.55% Test: 69.42%
# Epoch: 57, Loss: 0.9881, Train: 71.90%, Valid: 70.78% Test: 69.75%
# Epoch: 58, Loss: 0.9840, Train: 71.81%, Valid: 70.66% Test: 70.25%
# Epoch: 59, Loss: 0.9820, Train: 71.76%, Valid: 70.68% Test: 70.32%
# Epoch: 60, Loss: 0.9821, Train: 71.88%, Valid: 70.74% Test: 70.06%
# Epoch: 61, Loss: 0.9812, Train: 71.93%, Valid: 70.69% Test: 70.11%
# Epoch: 62, Loss: 0.9753, Train: 72.07%, Valid: 70.77% Test: 70.13%
# Epoch: 63, Loss: 0.9736, Train: 72.00%, Valid: 70.68% Test: 69.65%
# Epoch: 64, Loss: 0.9736, Train: 72.06%, Valid: 70.46% Test: 69.22%
# Epoch: 65, Loss: 0.9696, Train: 72.27%, Valid: 70.55% Test: 69.18%
# Epoch: 66, Loss: 0.9682, Train: 72.35%, Valid: 71.07% Test: 70.18%
# Epoch: 67, Loss: 0.9644, Train: 72.40%, Valid: 71.12% Test: 70.50%
# Epoch: 68, Loss: 0.9635, Train: 72.56%, Valid: 71.30% Test: 70.47%
# Epoch: 69, Loss: 0.9609, Train: 72.66%, Valid: 71.31% Test: 70.52%
# Epoch: 70, Loss: 0.9583, Train: 72.69%, Valid: 71.33% Test: 70.58%
# Epoch: 71, Loss: 0.9566, Train: 72.75%, Valid: 71.30% Test: 70.09%
# Epoch: 72, Loss: 0.9566, Train: 72.74%, Valid: 70.95% Test: 69.40%
# Epoch: 73, Loss: 0.9553, Train: 72.70%, Valid: 71.02% Test: 69.93%
# Epoch: 74, Loss: 0.9527, Train: 72.69%, Valid: 71.01% Test: 70.19%
# Epoch: 75, Loss: 0.9484, Train: 72.88%, Valid: 71.51% Test: 70.62%
# Epoch: 76, Loss: 0.9481, Train: 72.84%, Valid: 71.52% Test: 70.84%
# Epoch: 77, Loss: 0.9449, Train: 72.81%, Valid: 71.36% Test: 71.06%
# Epoch: 78, Loss: 0.9472, Train: 72.99%, Valid: 71.68% Test: 71.08%
# Epoch: 79, Loss: 0.9459, Train: 72.98%, Valid: 71.52% Test: 70.53%
# Epoch: 80, Loss: 0.9437, Train: 72.94%, Valid: 71.18% Test: 70.18%
# Epoch: 81, Loss: 0.9397, Train: 73.00%, Valid: 71.22% Test: 70.08%
# Epoch: 82, Loss: 0.9383, Train: 73.19%, Valid: 71.54% Test: 70.59%
# Epoch: 83, Loss: 0.9388, Train: 73.06%, Valid: 71.60% Test: 71.18%
# Epoch: 84, Loss: 0.9355, Train: 72.86%, Valid: 71.30% Test: 71.27%
# Epoch: 85, Loss: 0.9333, Train: 73.24%, Valid: 71.50% Test: 70.80%
# Epoch: 86, Loss: 0.9342, Train: 73.32%, Valid: 71.20% Test: 69.74%
# Epoch: 87, Loss: 0.9312, Train: 73.32%, Valid: 71.52% Test: 70.50%
# Epoch: 88, Loss: 0.9277, Train: 73.27%, Valid: 71.39% Test: 70.30%
# Epoch: 89, Loss: 0.9256, Train: 73.05%, Valid: 71.00% Test: 69.58%
# Epoch: 90, Loss: 0.9257, Train: 73.22%, Valid: 71.43% Test: 70.29%
# Epoch: 91, Loss: 0.9226, Train: 73.35%, Valid: 71.54% Test: 71.20%
# Epoch: 92, Loss: 0.9247, Train: 73.34%, Valid: 71.76% Test: 71.28%
# Epoch: 93, Loss: 0.9201, Train: 73.32%, Valid: 70.91% Test: 69.20%
# Epoch: 94, Loss: 0.9195, Train: 73.68%, Valid: 71.57% Test: 70.58%
# Epoch: 95, Loss: 0.9180, Train: 73.58%, Valid: 71.50% Test: 71.03%
# Epoch: 96, Loss: 0.9194, Train: 73.69%, Valid: 71.30% Test: 70.31%
# Epoch: 97, Loss: 0.9138, Train: 73.59%, Valid: 70.64% Test: 69.05%
# Epoch: 98, Loss: 0.9150, Train: 73.71%, Valid: 71.34% Test: 70.31%
# Epoch: 99, Loss: 0.9110, Train: 73.79%, Valid: 71.86% Test: 71.21%
# Epoch: 100, Loss: 0.9110, Train: 73.80%, Valid: 71.96% Test: 71.13%
